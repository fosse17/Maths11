# %% [raw]
# # Présentation de Maths Discrètes
#
# L'objectif de ce module est de mettre en place les outils mathématiques nécessaires aux bases de l'informatique.
#
# Cette ressource aide à formaliser et mettre en œuvre des outils mathématiques pour l’informatique et à concevoir et mettre en place une base de données à partir d’un cahier des charges client en donnant toutes les bases des mathématiques discrètes.
#
# • Logique (prédicats, propositions...)
# • Théorie des ensembles
# • Dénombrement
# • Algèbre de Boole
# • Arithmétique modulaire
# • Relations, applications
# • Numération
#
# ## Volume horaire
#
# - 16 TD et 4 TP de deux heures
#
# ## Détails par séance
#
# ### S1 (2TD) - Semaine 36
#
# - Logique 1
#
#
# - Numération 1
#
#
# ### S2 (2TD) -  Semaine 37
#
# - Logique 2
#
#
# - Numération 2
#
#
# ### S3 (2TD) - Semaine 38
#
#
# - Logique 3
#
#
# - Numérat
#
#
# ### S4 (2TD) -  Semaine 39
#
# - Logique 4
#
#
# - Congruence
#
#
# ### S5 (2TD) -  Semaine 40
#
# - Quantificateur
#
#
# - PGCD, bezout et Gauss
#
#
#
# ### S6  (2TD) - Semaine 41
#
# - Démonstration 1
#
#
# - Nombre premiers et exercices de synthèse
#
#
# ### S7 (2TD) - Semaine 42
#
# - Démonstration 2
#
#
# - Exercice de synthèse
#
# ### S8 (1TD 1TP ) - Semaine 43
#
# - Dénombrement 1
#
#
#
# ### S9 (1 TD 1TP)- Semaine 45
#
# - Dénombrement 2
#
#
# -
#
# ### S10 (1TP) - semaine 46
#
# -
#
#
# -
#
#
# ### S11 (1TP) - semaine 47
